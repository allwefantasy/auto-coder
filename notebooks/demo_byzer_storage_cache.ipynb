# %% [markdown]
# # 演示 ByzerStorageCache 的使用
#
# 本演示展示了如何使用 ByzerStorageCache 进行文档的存储和检索。

# %%
import os
from autocoder.rag.cache.byzer_storage_cache import ByzerStorageCache
from autocoder.common import SourceCode

# %% [markdown]
# ## 1. 初始化 ByzerStorageCache
#
# 首先我们需要创建一个 ByzerStorageCache 实例。

# %%
# 设置示例路径和过滤规则
path = "/Users/allwefantasy/projects/ray/doc/source"
ignore_spec = None  # 可以使用 pathspec 创建忽略规则
required_exts = [".md", ".rst"]  # 只处理这些扩展名的文件

# 创建 ByzerStorageCache 实例
cache = ByzerStorageCache(path, ignore_spec, required_exts)
# Out:
# 2024-10-23 20:46:25.714 | INFO     | byzerllm.utils.connect_ray:connect_cluster:48 - JDK 21 will be used (/Users/allwefantasy/.auto-coder/jdk-21.0.2.jdk/Contents/Home)...
# 2024-10-23 20:46:25,853	INFO worker.py:1564 -- Connecting to existing Ray cluster at address: 127.0.0.1:6379...
# 2024-10-23 20:46:25,945	INFO worker.py:1740 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# 21

# %% [markdown]
# ## 2. 获取缓存内容

# %%
# 获取所有缓存的文档
cache.build_cache()
# Out:
# 2024-10-23 20:46:34.812 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:110 - Building cache for path: /Users/allwefantasy/projects/ray/doc/source
# 2024-10-23 20:46:34.949 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.950 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_includes/_help.rst in 0.001455068588256836
# 2024-10-23 20:46:34.951 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_includes/_help.rst
# 2024-10-23 20:46:34.953 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.954 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_includes/_latest_contribution_doc.rst in 0.0012631416320800781
# 2024-10-23 20:46:34.954 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_includes/_latest_contribution_doc.rst
# 2024-10-23 20:46:34.957 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.958 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_includes/rllib/rlm_learner_migration_banner.rst in 0.0014760494232177734
# 2024-10-23 20:46:34.959 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_includes/rllib/rlm_learner_migration_banner.rst
# 2024-10-23 20:46:34.961 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.962 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_includes/rllib/rlmodules_rollout.rst in 0.0013470649719238281
# 2024-10-23 20:46:34.962 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_includes/rllib/rlmodules_rollout.rst
# 2024-10-23 20:46:34.966 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.966 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_includes/rllib/we_are_hiring.rst in 0.0016150474548339844
# 2024-10-23 20:46:34.969 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_includes/rllib/we_are_hiring.rst
# 2024-10-23 20:46:34.973 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.974 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_templates/autosummary/class.rst in 0.0016489028930664062
# 2024-10-23 20:46:34.974 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_templates/autosummary/class.rst
# 2024-10-23 20:46:34.977 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.978 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_templates/autosummary/class_without_autosummary.rst in 0.0017611980438232422
# 2024-10-23 20:46:34.979 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_templates/autosummary/class_without_autosummary.rst
# 2024-10-23 20:46:34.981 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.982 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_templates/autosummary/class_without_init_args.rst in 0.0013201236724853516
# 2024-10-23 20:46:34.983 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_templates/autosummary/class_without_init_args.rst
# 2024-10-23 20:46:34.985 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.986 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source/_templates/template.md in 0.0014901161193847656
# 2024-10-23 20:46:34.987 | INFO     | autocoder.rag.cache.byzer_storage_cache:build_cache:129 - Processing file: ##File: /Users/allwefantasy/projects/ray/doc/source/_templates/template.md
# 2024-10-23 20:46:34.991 | ERROR    | autocoder.rag.token_counter:count_tokens_worker:50 - Error counting tokens: name 'tokenizer_model' is not defined
# 2024-10-23 20:46:34.992 | INFO     | autocoder.rag.utils:process_file_in_multi_process:68 - Load file /Users/allwefantasy/projects/ray/doc/source
# %% [markdown]
# ## 3. 搜索缓存内容

# %%
# 设置搜索选项
search_options = {
    "query": "Ray Actor 创建",
    "enable_vector_search": True,
    "enable_text_search": True
}

# 执行搜索
search_results = list(cache.get_cache(search_options))

# 打印搜索结果
for doc in search_results:
    print(f"\nFound in: {doc.module_name}")
    print(f"Content preview: {doc.source_code[:100]}...")
# Out:
# 2024-10-23 20:52:15.996 | INFO     | autocoder.rag.cache.byzer_storage_cache:update_cache:199 - Checking for file updates...
# 2024-10-23 20:52:16.101 | INFO     | autocoder.rag.cache.byzer_storage_cache:update_cache:266 - No file updates found
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# Content preview: .. _ray-core-mem-profiling:
#
# Debugging Memory Issues
# =======================
#
#
# .. _troubleshooting-o...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/terminating-actors.rst
# Content preview: Terminating Actors
# ==================
#
# Actor processes will be terminated automatically when all cop...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/task-orders.rst
# Content preview: .. _actor-task-order:
#
# Actor Task Execution Order
# ==========================
#
# Synchronous, Single-Th...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-failures.rst
# Content preview: .. _observability-debug-failures:
#
# Debugging Failures
# ==================
#
# What Kind of Failures Exis...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/named-actors.rst
# Content preview: Named Actors
# ============
#
# An actor can be given a unique name within their :ref:`namespace <namespa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/walkthrough.rst
# Content preview: .. _core-walkthrough:
#
# What is Ray Core?
# =================
#
# Ray Core provides a small number of core...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/plot_example-lm.rst
# Content preview: Fault-Tolerant Fairseq Training
# ===============================
#
# .. note::
#     For an overview of Ra...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/namespaces.rst
# Content preview: .. _namespaces-guide:
#
# Using Namespaces
# ================
#
# A namespace is a logical grouping of jobs ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/getting-started.rst
# Content preview: .. _observability-getting-started:
#
# Ray Dashboard
# =============
#
# Ray provides a web-based dashboard ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-dag.rst
# Content preview: .. _ray-dag-guide:
#
# Lazy Computation Graphs with the Ray DAG API
# ===================================...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors.rst
# Content preview: .. _ray-remote-classes:
# .. _actor-guide:
#
# Actors
# ======
#
# Actors extend the Ray API from functions (t...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/architecture.md
# Content preview: (serve-architecture)=
#
# # Architecture
#
# In this section, we explore Serve's key architectural concept...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/key-concepts.rst
# Content preview: .. _observability-key-concepts:
#
# Key Concepts
# ============
#
# This section covers key concepts for mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-overview/getting-started.md
# Content preview: (gentle-intro)=
#
# # Getting Started
# Use Ray to scale applications on your laptop or the cloud. Choose...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/configure-logging.md
# Content preview: (configure-logging)=
#
# # Configuring Logging
#
# This guide helps you understand and modify the configur...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/monte_carlo_pi.rst
# Content preview: .. _monte-carlo-pi:
#
# Monte Carlo Estimation of π
# ===========================
#
# This tutorial shows yo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/profiling.md
# Content preview: (profiling)=
# # Profiling
# Profiling is one of the most important debugging tools to diagnose performa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/placement-group.rst
# Content preview: Placement Groups
# ================
#
# .. _ray-placement-group-doc-ref:
#
# Placement groups allow users to...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/async_api.rst
# Content preview: AsyncIO / Concurrency for Actors
# ================================
#
# Within a single actor process, it...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/configure-serve-deployment.md
# Content preview: (serve-configure-deployment)=
#
# # Configure Ray Serve deployments
#
# Ray Serve default values for deplo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/miscellaneous.rst
# Content preview: Miscellaneous Topics
# ====================
#
# This page will cover some miscellaneous topics in Ray.
#
# ....
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-generator.rst
# Content preview: .. _generators:
#
# Ray Generators
# ==============
#
# `Python generators <https://docs.python.org/3/howto...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/actor-utils.rst
# Content preview: Utility Classes
# ===============
#
# Actor Pool
# ~~~~~~~~~~
#
# .. tab-set::
#
#     .. tab-item:: Python
#
#     ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-references/glossary.rst
# Content preview: .. _ray_glossary:
#
# Ray Glossary
# ============
#
# On this page you find a list of important terminology ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/objects.rst
# Content preview: .. _objects-in-ray:
#
# Objects
# =======
#
# In Ray, tasks and actors create and compute on objects. We ref...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/handling-dependencies.rst
# Content preview: .. _handling_dependencies:
#
# Environment Dependencies
# ========================
#
# Your Ray application ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/cli-sdk.rst
# Content preview: .. _observability-programmatic:
#
# Monitoring with the CLI or SDK
# ===============================
#
# Mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/fault_tolerance/actors.rst
# Content preview: .. _fault-tolerance-actors:
# .. _actor-fault-tolerance:
#
# Actor Fault Tolerance
# =====================
# ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/kuberay-gcs-ft.md
# Content preview: (kuberay-gcs-ft)=
# # GCS fault tolerance in KubeRay
#
# Global Control Service (GCS) manages cluster-lev...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/key-concepts.rst
# Content preview: .. _core-key-concepts:
#
# Key Concepts
# ============
#
# This section overviews Ray's key concepts. These ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/memory-management.rst
# Content preview: .. _memory:
#
# Memory Management
# =================
#
# This page describes how memory management works in...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/resources.rst
# Content preview: .. _core-resources:
#
# Resources
# =========
#
# Ray allows you to seamlessly scale your applications from ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-more-libs/modin/index.rst
# Content preview: .. _modin-on-ray:
#
# Using Pandas on Ray (Modin)
# ===========================
#
# Modin_, previously Panda...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/cross-language.rst
# Content preview: .. _cross_language:
#
# Cross-Language Programming
# ==========================
#
# This page will show you ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/production-guide/fault-tolerance.md
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# Content preview: .. _ray-core-mem-profiling:
#
# Debugging Memory Issues
# =======================
#
#
# .. _troubleshooting-o...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/terminating-actors.rst
# Content preview: Terminating Actors
# ==================
#
# Actor processes will be terminated automatically when all cop...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/task-orders.rst
# Content preview: .. _actor-task-order:
#
# Actor Task Execution Order
# ==========================
#
# Synchronous, Single-Th...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-failures.rst
# Content preview: .. _observability-debug-failures:
#
# Debugging Failures
# ==================
#
# What Kind of Failures Exis...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/named-actors.rst
# Content preview: Named Actors
# ============
#
# An actor can be given a unique name within their :ref:`namespace <namespa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/walkthrough.rst
# Content preview: .. _core-walkthrough:
#
# What is Ray Core?
# =================
#
# Ray Core provides a small number of core...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/plot_example-lm.rst
# Content preview: Fault-Tolerant Fairseq Training
# ===============================
#
# .. note::
#     For an overview of Ra...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/namespaces.rst
# Content preview: .. _namespaces-guide:
#
# Using Namespaces
# ================
#
# A namespace is a logical grouping of jobs ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/getting-started.rst
# Content preview: .. _observability-getting-started:
#
# Ray Dashboard
# =============
#
# Ray provides a web-based dashboard ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-dag.rst
# Content preview: .. _ray-dag-guide:
#
# Lazy Computation Graphs with the Ray DAG API
# ===================================...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors.rst
# Content preview: .. _ray-remote-classes:
# .. _actor-guide:
#
# Actors
# ======
#
# Actors extend the Ray API from functions (t...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/architecture.md
# Content preview: (serve-architecture)=
#
# # Architecture
#
# In this section, we explore Serve's key architectural concept...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/key-concepts.rst
# Content preview: .. _observability-key-concepts:
#
# Key Concepts
# ============
#
# This section covers key concepts for mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-overview/getting-started.md
# Content preview: (gentle-intro)=
#
# # Getting Started
# Use Ray to scale applications on your laptop or the cloud. Choose...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/configure-logging.md
# Content preview: (configure-logging)=
#
# # Configuring Logging
#
# This guide helps you understand and modify the configur...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/monte_carlo_pi.rst
# Content preview: .. _monte-carlo-pi:
#
# Monte Carlo Estimation of π
# ===========================
#
# This tutorial shows yo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/profiling.md
# Content preview: (profiling)=
# # Profiling
# Profiling is one of the most important debugging tools to diagnose performa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/placement-group.rst
# Content preview: Placement Groups
# ================
#
# .. _ray-placement-group-doc-ref:
#
# Placement groups allow users to...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/async_api.rst
# Content preview: AsyncIO / Concurrency for Actors
# ================================
#
# Within a single actor process, it...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/configure-serve-deployment.md
# Content preview: (serve-configure-deployment)=
#
# # Configure Ray Serve deployments
#
# Ray Serve default values for deplo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/miscellaneous.rst
# Content preview: Miscellaneous Topics
# ====================
#
# This page will cover some miscellaneous topics in Ray.
#
# ....
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-generator.rst
# Content preview: .. _generators:
#
# Ray Generators
# ==============
#
# `Python generators <https://docs.python.org/3/howto...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/actor-utils.rst
# Content preview: Utility Classes
# ===============
#
# Actor Pool
# ~~~~~~~~~~
#
# .. tab-set::
#
#     .. tab-item:: Python
#
#     ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-references/glossary.rst
# Content preview: .. _ray_glossary:
#
# Ray Glossary
# ============
#
# On this page you find a list of important terminology ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/objects.rst
# Content preview: .. _objects-in-ray:
#
# Objects
# =======
#
# In Ray, tasks and actors create and compute on objects. We ref...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/handling-dependencies.rst
# Content preview: .. _handling_dependencies:
#
# Environment Dependencies
# ========================
#
# Your Ray application ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/cli-sdk.rst
# Content preview: .. _observability-programmatic:
#
# Monitoring with the CLI or SDK
# ===============================
#
# Mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/fault_tolerance/actors.rst
# Content preview: .. _fault-tolerance-actors:
# .. _actor-fault-tolerance:
#
# Actor Fault Tolerance
# =====================
# ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/kuberay-gcs-ft.md
# Content preview: (kuberay-gcs-ft)=
# # GCS fault tolerance in KubeRay
#
# Global Control Service (GCS) manages cluster-lev...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/key-concepts.rst
# Content preview: .. _core-key-concepts:
#
# Key Concepts
# ============
#
# This section overviews Ray's key concepts. These ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/memory-management.rst
# Content preview: .. _memory:
#
# Memory Management
# =================
#
# This page describes how memory management works in...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/resources.rst
# Content preview: .. _core-resources:
#
# Resources
# =========
#
# Ray allows you to seamlessly scale your applications from ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-more-libs/modin/index.rst
# Content preview: .. _modin-on-ray:
#
# Using Pandas on Ray (Modin)
# ===========================
#
# Modin_, previously Panda...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/cross-language.rst
# Content preview: .. _cross_language:
#
# Cross-Language Programming
# ==========================
#
# This page will show you ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/production-guide/fault-tolerance.md
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# Content preview: .. _ray-core-mem-profiling:
#
# Debugging Memory Issues
# =======================
#
#
# .. _troubleshooting-o...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/terminating-actors.rst
# Content preview: Terminating Actors
# ==================
#
# Actor processes will be terminated automatically when all cop...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/task-orders.rst
# Content preview: .. _actor-task-order:
#
# Actor Task Execution Order
# ==========================
#
# Synchronous, Single-Th...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-failures.rst
# Content preview: .. _observability-debug-failures:
#
# Debugging Failures
# ==================
#
# What Kind of Failures Exis...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/named-actors.rst
# Content preview: Named Actors
# ============
#
# An actor can be given a unique name within their :ref:`namespace <namespa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/walkthrough.rst
# Content preview: .. _core-walkthrough:
#
# What is Ray Core?
# =================
#
# Ray Core provides a small number of core...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/plot_example-lm.rst
# Content preview: Fault-Tolerant Fairseq Training
# ===============================
#
# .. note::
#     For an overview of Ra...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/namespaces.rst
# Content preview: .. _namespaces-guide:
#
# Using Namespaces
# ================
#
# A namespace is a logical grouping of jobs ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/getting-started.rst
# Content preview: .. _observability-getting-started:
#
# Ray Dashboard
# =============
#
# Ray provides a web-based dashboard ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-dag.rst
# Content preview: .. _ray-dag-guide:
#
# Lazy Computation Graphs with the Ray DAG API
# ===================================...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors.rst
# Content preview: .. _ray-remote-classes:
# .. _actor-guide:
#
# Actors
# ======
#
# Actors extend the Ray API from functions (t...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/architecture.md
# Content preview: (serve-architecture)=
#
# # Architecture
#
# In this section, we explore Serve's key architectural concept...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/key-concepts.rst
# Content preview: .. _observability-key-concepts:
#
# Key Concepts
# ============
#
# This section covers key concepts for mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-overview/getting-started.md
# Content preview: (gentle-intro)=
#
# # Getting Started
# Use Ray to scale applications on your laptop or the cloud. Choose...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/configure-logging.md
# Content preview: (configure-logging)=
#
# # Configuring Logging
#
# This guide helps you understand and modify the configur...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/monte_carlo_pi.rst
# Content preview: .. _monte-carlo-pi:
#
# Monte Carlo Estimation of π
# ===========================
#
# This tutorial shows yo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/profiling.md
# Content preview: (profiling)=
# # Profiling
# Profiling is one of the most important debugging tools to diagnose performa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/placement-group.rst
# Content preview: Placement Groups
# ================
#
# .. _ray-placement-group-doc-ref:
#
# Placement groups allow users to...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/async_api.rst
# Content preview: AsyncIO / Concurrency for Actors
# ================================
#
# Within a single actor process, it...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/configure-serve-deployment.md
# Content preview: (serve-configure-deployment)=
#
# # Configure Ray Serve deployments
#
# Ray Serve default values for deplo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/miscellaneous.rst
# Content preview: Miscellaneous Topics
# ====================
#
# This page will cover some miscellaneous topics in Ray.
#
# ....
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-generator.rst
# Content preview: .. _generators:
#
# Ray Generators
# ==============
#
# `Python generators <https://docs.python.org/3/howto...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/actor-utils.rst
# Content preview: Utility Classes
# ===============
#
# Actor Pool
# ~~~~~~~~~~
#
# .. tab-set::
#
#     .. tab-item:: Python
#
#     ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-references/glossary.rst
# Content preview: .. _ray_glossary:
#
# Ray Glossary
# ============
#
# On this page you find a list of important terminology ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/objects.rst
# Content preview: .. _objects-in-ray:
#
# Objects
# =======
#
# In Ray, tasks and actors create and compute on objects. We ref...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/handling-dependencies.rst
# Content preview: .. _handling_dependencies:
#
# Environment Dependencies
# ========================
#
# Your Ray application ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/cli-sdk.rst
# Content preview: .. _observability-programmatic:
#
# Monitoring with the CLI or SDK
# ===============================
#
# Mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/fault_tolerance/actors.rst
# Content preview: .. _fault-tolerance-actors:
# .. _actor-fault-tolerance:
#
# Actor Fault Tolerance
# =====================
# ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/kuberay-gcs-ft.md
# Content preview: (kuberay-gcs-ft)=
# # GCS fault tolerance in KubeRay
#
# Global Control Service (GCS) manages cluster-lev...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/key-concepts.rst
# Content preview: .. _core-key-concepts:
#
# Key Concepts
# ============
#
# This section overviews Ray's key concepts. These ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/memory-management.rst
# Content preview: .. _memory:
#
# Memory Management
# =================
#
# This page describes how memory management works in...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/resources.rst
# Content preview: .. _core-resources:
#
# Resources
# =========
#
# Ray allows you to seamlessly scale your applications from ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-more-libs/modin/index.rst
# Content preview: .. _modin-on-ray:
#
# Using Pandas on Ray (Modin)
# ===========================
#
# Modin_, previously Panda...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/cross-language.rst
# Content preview: .. _cross_language:
#
# Cross-Language Programming
# ==========================
#
# This page will show you ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/production-guide/fault-tolerance.md
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# Content preview: .. _ray-core-mem-profiling:
#
# Debugging Memory Issues
# =======================
#
#
# .. _troubleshooting-o...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/terminating-actors.rst
# Content preview: Terminating Actors
# ==================
#
# Actor processes will be terminated automatically when all cop...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/task-orders.rst
# Content preview: .. _actor-task-order:
#
# Actor Task Execution Order
# ==========================
#
# Synchronous, Single-Th...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-failures.rst
# Content preview: .. _observability-debug-failures:
#
# Debugging Failures
# ==================
#
# What Kind of Failures Exis...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/named-actors.rst
# Content preview: Named Actors
# ============
#
# An actor can be given a unique name within their :ref:`namespace <namespa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/walkthrough.rst
# Content preview: .. _core-walkthrough:
#
# What is Ray Core?
# =================
#
# Ray Core provides a small number of core...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/plot_example-lm.rst
# Content preview: Fault-Tolerant Fairseq Training
# ===============================
#
# .. note::
#     For an overview of Ra...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/namespaces.rst
# Content preview: .. _namespaces-guide:
#
# Using Namespaces
# ================
#
# A namespace is a logical grouping of jobs ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/getting-started.rst
# Content preview: .. _observability-getting-started:
#
# Ray Dashboard
# =============
#
# Ray provides a web-based dashboard ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-dag.rst
# Content preview: .. _ray-dag-guide:
#
# Lazy Computation Graphs with the Ray DAG API
# ===================================...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors.rst
# Content preview: .. _ray-remote-classes:
# .. _actor-guide:
#
# Actors
# ======
#
# Actors extend the Ray API from functions (t...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/architecture.md
# Content preview: (serve-architecture)=
#
# # Architecture
#
# In this section, we explore Serve's key architectural concept...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/key-concepts.rst
# Content preview: .. _observability-key-concepts:
#
# Key Concepts
# ============
#
# This section covers key concepts for mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-overview/getting-started.md
# Content preview: (gentle-intro)=
#
# # Getting Started
# Use Ray to scale applications on your laptop or the cloud. Choose...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/configure-logging.md
# Content preview: (configure-logging)=
#
# # Configuring Logging
#
# This guide helps you understand and modify the configur...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/monte_carlo_pi.rst
# Content preview: .. _monte-carlo-pi:
#
# Monte Carlo Estimation of π
# ===========================
#
# This tutorial shows yo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/profiling.md
# Content preview: (profiling)=
# # Profiling
# Profiling is one of the most important debugging tools to diagnose performa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/placement-group.rst
# Content preview: Placement Groups
# ================
#
# .. _ray-placement-group-doc-ref:
#
# Placement groups allow users to...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/async_api.rst
# Content preview: AsyncIO / Concurrency for Actors
# ================================
#
# Within a single actor process, it...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/configure-serve-deployment.md
# Content preview: (serve-configure-deployment)=
#
# # Configure Ray Serve deployments
#
# Ray Serve default values for deplo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/miscellaneous.rst
# Content preview: Miscellaneous Topics
# ====================
#
# This page will cover some miscellaneous topics in Ray.
#
# ....
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-generator.rst
# Content preview: .. _generators:
#
# Ray Generators
# ==============
#
# `Python generators <https://docs.python.org/3/howto...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/actor-utils.rst
# Content preview: Utility Classes
# ===============
#
# Actor Pool
# ~~~~~~~~~~
#
# .. tab-set::
#
#     .. tab-item:: Python
#
#     ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-references/glossary.rst
# Content preview: .. _ray_glossary:
#
# Ray Glossary
# ============
#
# On this page you find a list of important terminology ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/objects.rst
# Content preview: .. _objects-in-ray:
#
# Objects
# =======
#
# In Ray, tasks and actors create and compute on objects. We ref...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/handling-dependencies.rst
# Content preview: .. _handling_dependencies:
#
# Environment Dependencies
# ========================
#
# Your Ray application ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/cli-sdk.rst
# Content preview: .. _observability-programmatic:
#
# Monitoring with the CLI or SDK
# ===============================
#
# Mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/fault_tolerance/actors.rst
# Content preview: .. _fault-tolerance-actors:
# .. _actor-fault-tolerance:
#
# Actor Fault Tolerance
# =====================
# ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/kuberay-gcs-ft.md
# Content preview: (kuberay-gcs-ft)=
# # GCS fault tolerance in KubeRay
#
# Global Control Service (GCS) manages cluster-lev...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/key-concepts.rst
# Content preview: .. _core-key-concepts:
#
# Key Concepts
# ============
#
# This section overviews Ray's key concepts. These ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/memory-management.rst
# Content preview: .. _memory:
#
# Memory Management
# =================
#
# This page describes how memory management works in...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/resources.rst
# Content preview: .. _core-resources:
#
# Resources
# =========
#
# Ray allows you to seamlessly scale your applications from ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-more-libs/modin/index.rst
# Content preview: .. _modin-on-ray:
#
# Using Pandas on Ray (Modin)
# ===========================
#
# Modin_, previously Panda...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/cross-language.rst
# Content preview: .. _cross_language:
#
# Cross-Language Programming
# ==========================
#
# This page will show you ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/production-guide/fault-tolerance.md
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# Content preview: .. _ray-core-mem-profiling:
#
# Debugging Memory Issues
# =======================
#
#
# .. _troubleshooting-o...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/terminating-actors.rst
# Content preview: Terminating Actors
# ==================
#
# Actor processes will be terminated automatically when all cop...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/task-orders.rst
# Content preview: .. _actor-task-order:
#
# Actor Task Execution Order
# ==========================
#
# Synchronous, Single-Th...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-failures.rst
# Content preview: .. _observability-debug-failures:
#
# Debugging Failures
# ==================
#
# What Kind of Failures Exis...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/named-actors.rst
# Content preview: Named Actors
# ============
#
# An actor can be given a unique name within their :ref:`namespace <namespa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/walkthrough.rst
# Content preview: .. _core-walkthrough:
#
# What is Ray Core?
# =================
#
# Ray Core provides a small number of core...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/plot_example-lm.rst
# Content preview: Fault-Tolerant Fairseq Training
# ===============================
#
# .. note::
#     For an overview of Ra...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/namespaces.rst
# Content preview: .. _namespaces-guide:
#
# Using Namespaces
# ================
#
# A namespace is a logical grouping of jobs ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/getting-started.rst
# Content preview: .. _observability-getting-started:
#
# Ray Dashboard
# =============
#
# Ray provides a web-based dashboard ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-dag.rst
# Content preview: .. _ray-dag-guide:
#
# Lazy Computation Graphs with the Ray DAG API
# ===================================...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors.rst
# Content preview: .. _ray-remote-classes:
# .. _actor-guide:
#
# Actors
# ======
#
# Actors extend the Ray API from functions (t...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/architecture.md
# Content preview: (serve-architecture)=
#
# # Architecture
#
# In this section, we explore Serve's key architectural concept...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/key-concepts.rst
# Content preview: .. _observability-key-concepts:
#
# Key Concepts
# ============
#
# This section covers key concepts for mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-overview/getting-started.md
# Content preview: (gentle-intro)=
#
# # Getting Started
# Use Ray to scale applications on your laptop or the cloud. Choose...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/configure-logging.md
# Content preview: (configure-logging)=
#
# # Configuring Logging
#
# This guide helps you understand and modify the configur...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/monte_carlo_pi.rst
# Content preview: .. _monte-carlo-pi:
#
# Monte Carlo Estimation of π
# ===========================
#
# This tutorial shows yo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/profiling.md
# Content preview: (profiling)=
# # Profiling
# Profiling is one of the most important debugging tools to diagnose performa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/placement-group.rst
# Content preview: Placement Groups
# ================
#
# .. _ray-placement-group-doc-ref:
#
# Placement groups allow users to...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/async_api.rst
# Content preview: AsyncIO / Concurrency for Actors
# ================================
#
# Within a single actor process, it...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/configure-serve-deployment.md
# Content preview: (serve-configure-deployment)=
#
# # Configure Ray Serve deployments
#
# Ray Serve default values for deplo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/miscellaneous.rst
# Content preview: Miscellaneous Topics
# ====================
#
# This page will cover some miscellaneous topics in Ray.
#
# ....
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-generator.rst
# Content preview: .. _generators:
#
# Ray Generators
# ==============
#
# `Python generators <https://docs.python.org/3/howto...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/actor-utils.rst
# Content preview: Utility Classes
# ===============
#
# Actor Pool
# ~~~~~~~~~~
#
# .. tab-set::
#
#     .. tab-item:: Python
#
#     ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-references/glossary.rst
# Content preview: .. _ray_glossary:
#
# Ray Glossary
# ============
#
# On this page you find a list of important terminology ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/objects.rst
# Content preview: .. _objects-in-ray:
#
# Objects
# =======
#
# In Ray, tasks and actors create and compute on objects. We ref...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/handling-dependencies.rst
# Content preview: .. _handling_dependencies:
#
# Environment Dependencies
# ========================
#
# Your Ray application ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/cli-sdk.rst
# Content preview: .. _observability-programmatic:
#
# Monitoring with the CLI or SDK
# ===============================
#
# Mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/fault_tolerance/actors.rst
# Content preview: .. _fault-tolerance-actors:
# .. _actor-fault-tolerance:
#
# Actor Fault Tolerance
# =====================
# ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/kuberay-gcs-ft.md
# Content preview: (kuberay-gcs-ft)=
# # GCS fault tolerance in KubeRay
#
# Global Control Service (GCS) manages cluster-lev...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/key-concepts.rst
# Content preview: .. _core-key-concepts:
#
# Key Concepts
# ============
#
# This section overviews Ray's key concepts. These ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/memory-management.rst
# Content preview: .. _memory:
#
# Memory Management
# =================
#
# This page describes how memory management works in...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/resources.rst
# Content preview: .. _core-resources:
#
# Resources
# =========
#
# Ray allows you to seamlessly scale your applications from ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-more-libs/modin/index.rst
# Content preview: .. _modin-on-ray:
#
# Using Pandas on Ray (Modin)
# ===========================
#
# Modin_, previously Panda...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/cross-language.rst
# Content preview: .. _cross_language:
#
# Cross-Language Programming
# ==========================
#
# This page will show you ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/production-guide/fault-tolerance.md
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# Content preview: .. _ray-core-mem-profiling:
#
# Debugging Memory Issues
# =======================
#
#
# .. _troubleshooting-o...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/terminating-actors.rst
# Content preview: Terminating Actors
# ==================
#
# Actor processes will be terminated automatically when all cop...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/task-orders.rst
# Content preview: .. _actor-task-order:
#
# Actor Task Execution Order
# ==========================
#
# Synchronous, Single-Th...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-failures.rst
# Content preview: .. _observability-debug-failures:
#
# Debugging Failures
# ==================
#
# What Kind of Failures Exis...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/named-actors.rst
# Content preview: Named Actors
# ============
#
# An actor can be given a unique name within their :ref:`namespace <namespa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/walkthrough.rst
# Content preview: .. _core-walkthrough:
#
# What is Ray Core?
# =================
#
# Ray Core provides a small number of core...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/plot_example-lm.rst
# Content preview: Fault-Tolerant Fairseq Training
# ===============================
#
# .. note::
#     For an overview of Ra...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/namespaces.rst
# Content preview: .. _namespaces-guide:
#
# Using Namespaces
# ================
#
# A namespace is a logical grouping of jobs ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/getting-started.rst
# Content preview: .. _observability-getting-started:
#
# Ray Dashboard
# =============
#
# Ray provides a web-based dashboard ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-dag.rst
# Content preview: .. _ray-dag-guide:
#
# Lazy Computation Graphs with the Ray DAG API
# ===================================...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors.rst
# Content preview: .. _ray-remote-classes:
# .. _actor-guide:
#
# Actors
# ======
#
# Actors extend the Ray API from functions (t...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/architecture.md
# Content preview: (serve-architecture)=
#
# # Architecture
#
# In this section, we explore Serve's key architectural concept...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/key-concepts.rst
# Content preview: .. _observability-key-concepts:
#
# Key Concepts
# ============
#
# This section covers key concepts for mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-overview/getting-started.md
# Content preview: (gentle-intro)=
#
# # Getting Started
# Use Ray to scale applications on your laptop or the cloud. Choose...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/configure-logging.md
# Content preview: (configure-logging)=
#
# # Configuring Logging
#
# This guide helps you understand and modify the configur...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/monte_carlo_pi.rst
# Content preview: .. _monte-carlo-pi:
#
# Monte Carlo Estimation of π
# ===========================
#
# This tutorial shows yo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/profiling.md
# Content preview: (profiling)=
# # Profiling
# Profiling is one of the most important debugging tools to diagnose performa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/placement-group.rst
# Content preview: Placement Groups
# ================
#
# .. _ray-placement-group-doc-ref:
#
# Placement groups allow users to...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/async_api.rst
# Content preview: AsyncIO / Concurrency for Actors
# ================================
#
# Within a single actor process, it...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/configure-serve-deployment.md
# Content preview: (serve-configure-deployment)=
#
# # Configure Ray Serve deployments
#
# Ray Serve default values for deplo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/miscellaneous.rst
# Content preview: Miscellaneous Topics
# ====================
#
# This page will cover some miscellaneous topics in Ray.
#
# ....
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-generator.rst
# Content preview: .. _generators:
#
# Ray Generators
# ==============
#
# `Python generators <https://docs.python.org/3/howto...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/actor-utils.rst
# Content preview: Utility Classes
# ===============
#
# Actor Pool
# ~~~~~~~~~~
#
# .. tab-set::
#
#     .. tab-item:: Python
#
#     ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-references/glossary.rst
# Content preview: .. _ray_glossary:
#
# Ray Glossary
# ============
#
# On this page you find a list of important terminology ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/objects.rst
# Content preview: .. _objects-in-ray:
#
# Objects
# =======
#
# In Ray, tasks and actors create and compute on objects. We ref...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/handling-dependencies.rst
# Content preview: .. _handling_dependencies:
#
# Environment Dependencies
# ========================
#
# Your Ray application ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/cli-sdk.rst
# Content preview: .. _observability-programmatic:
#
# Monitoring with the CLI or SDK
# ===============================
#
# Mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/fault_tolerance/actors.rst
# Content preview: .. _fault-tolerance-actors:
# .. _actor-fault-tolerance:
#
# Actor Fault Tolerance
# =====================
# ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/kuberay-gcs-ft.md
# Content preview: (kuberay-gcs-ft)=
# # GCS fault tolerance in KubeRay
#
# Global Control Service (GCS) manages cluster-lev...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/key-concepts.rst
# Content preview: .. _core-key-concepts:
#
# Key Concepts
# ============
#
# This section overviews Ray's key concepts. These ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/memory-management.rst
# Content preview: .. _memory:
#
# Memory Management
# =================
#
# This page describes how memory management works in...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/resources.rst
# Content preview: .. _core-resources:
#
# Resources
# =========
#
# Ray allows you to seamlessly scale your applications from ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-more-libs/modin/index.rst
# Content preview: .. _modin-on-ray:
#
# Using Pandas on Ray (Modin)
# ===========================
#
# Modin_, previously Panda...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/cross-language.rst
# Content preview: .. _cross_language:
#
# Cross-Language Programming
# ==========================
#
# This page will show you ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/production-guide/fault-tolerance.md
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# ...
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# Content preview: .. _ray-core-mem-profiling:
#
# Debugging Memory Issues
# =======================
#
#
# .. _troubleshooting-o...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/terminating-actors.rst
# Content preview: Terminating Actors
# ==================
#
# Actor processes will be terminated automatically when all cop...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/task-orders.rst
# Content preview: .. _actor-task-order:
#
# Actor Task Execution Order
# ==========================
#
# Synchronous, Single-Th...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-failures.rst
# Content preview: .. _observability-debug-failures:
#
# Debugging Failures
# ==================
#
# What Kind of Failures Exis...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/named-actors.rst
# Content preview: Named Actors
# ============
#
# An actor can be given a unique name within their :ref:`namespace <namespa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/walkthrough.rst
# Content preview: .. _core-walkthrough:
#
# What is Ray Core?
# =================
#
# Ray Core provides a small number of core...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/plot_example-lm.rst
# Content preview: Fault-Tolerant Fairseq Training
# ===============================
#
# .. note::
#     For an overview of Ra...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/namespaces.rst
# Content preview: .. _namespaces-guide:
#
# Using Namespaces
# ================
#
# A namespace is a logical grouping of jobs ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/getting-started.rst
# Content preview: .. _observability-getting-started:
#
# Ray Dashboard
# =============
#
# Ray provides a web-based dashboard ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-dag.rst
# Content preview: .. _ray-dag-guide:
#
# Lazy Computation Graphs with the Ray DAG API
# ===================================...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors.rst
# Content preview: .. _ray-remote-classes:
# .. _actor-guide:
#
# Actors
# ======
#
# Actors extend the Ray API from functions (t...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/architecture.md
# Content preview: (serve-architecture)=
#
# # Architecture
#
# In this section, we explore Serve's key architectural concept...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/key-concepts.rst
# Content preview: .. _observability-key-concepts:
#
# Key Concepts
# ============
#
# This section covers key concepts for mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-overview/getting-started.md
# Content preview: (gentle-intro)=
#
# # Getting Started
# Use Ray to scale applications on your laptop or the cloud. Choose...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/configure-logging.md
# Content preview: (configure-logging)=
#
# # Configuring Logging
#
# This guide helps you understand and modify the configur...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/monte_carlo_pi.rst
# Content preview: .. _monte-carlo-pi:
#
# Monte Carlo Estimation of π
# ===========================
#
# This tutorial shows yo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/profiling.md
# Content preview: (profiling)=
# # Profiling
# Profiling is one of the most important debugging tools to diagnose performa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/placement-group.rst
# Content preview: Placement Groups
# ================
#
# .. _ray-placement-group-doc-ref:
#
# Placement groups allow users to...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/async_api.rst
# Content preview: AsyncIO / Concurrency for Actors
# ================================
#
# Within a single actor process, it...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/configure-serve-deployment.md
# Content preview: (serve-configure-deployment)=
#
# # Configure Ray Serve deployments
#
# Ray Serve default values for deplo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/miscellaneous.rst
# Content preview: Miscellaneous Topics
# ====================
#
# This page will cover some miscellaneous topics in Ray.
#
# ....
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-generator.rst
# Content preview: .. _generators:
#
# Ray Generators
# ==============
#
# `Python generators <https://docs.python.org/3/howto...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/actor-utils.rst
# Content preview: Utility Classes
# ===============
#
# Actor Pool
# ~~~~~~~~~~
#
# .. tab-set::
#
#     .. tab-item:: Python
#
#     ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-references/glossary.rst
# Content preview: .. _ray_glossary:
#
# Ray Glossary
# ============
#
# On this page you find a list of important terminology ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/objects.rst
# Content preview: .. _objects-in-ray:
#
# Objects
# =======
#
# In Ray, tasks and actors create and compute on objects. We ref...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/handling-dependencies.rst
# Content preview: .. _handling_dependencies:
#
# Environment Dependencies
# ========================
#
# Your Ray application ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/cli-sdk.rst
# Content preview: .. _observability-programmatic:
#
# Monitoring with the CLI or SDK
# ===============================
#
# Mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/fault_tolerance/actors.rst
# Content preview: .. _fault-tolerance-actors:
# .. _actor-fault-tolerance:
#
# Actor Fault Tolerance
# =====================
# ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/kuberay-gcs-ft.md
# Content preview: (kuberay-gcs-ft)=
# # GCS fault tolerance in KubeRay
#
# Global Control Service (GCS) manages cluster-lev...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/key-concepts.rst
# Content preview: .. _core-key-concepts:
#
# Key Concepts
# ============
#
# This section overviews Ray's key concepts. These ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/memory-management.rst
# Content preview: .. _memory:
#
# Memory Management
# =================
#
# This page describes how memory management works in...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/resources.rst
# Content preview: .. _core-resources:
#
# Resources
# =========
#
# Ray allows you to seamlessly scale your applications from ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-more-libs/modin/index.rst
# Content preview: .. _modin-on-ray:
#
# Using Pandas on Ray (Modin)
# ===========================
#
# Modin_, previously Panda...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/cross-language.rst
# Content preview: .. _cross_language:
#
# Cross-Language Programming
# ==========================
#
# This page will show you ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/production-guide/fault-tolerance.md
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/configuring-autoscaling.md
# Content preview: (kuberay-autoscaling)=
#
# # KubeRay Autoscaling
#
# This guide explains how to configure the Ray Autoscal...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-memory.rst
# Content preview: .. _ray-core-mem-profiling:
#
# Debugging Memory Issues
# =======================
#
#
# .. _troubleshooting-o...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/terminating-actors.rst
# Content preview: Terminating Actors
# ==================
#
# Actor processes will be terminated automatically when all cop...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/task-orders.rst
# Content preview: .. _actor-task-order:
#
# Actor Task Execution Order
# ==========================
#
# Synchronous, Single-Th...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/debug-apps/debug-failures.rst
# Content preview: .. _observability-debug-failures:
#
# Debugging Failures
# ==================
#
# What Kind of Failures Exis...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/named-actors.rst
# Content preview: Named Actors
# ============
#
# An actor can be given a unique name within their :ref:`namespace <namespa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/walkthrough.rst
# Content preview: .. _core-walkthrough:
#
# What is Ray Core?
# =================
#
# Ray Core provides a small number of core...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/plot_example-lm.rst
# Content preview: Fault-Tolerant Fairseq Training
# ===============================
#
# .. note::
#     For an overview of Ra...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/namespaces.rst
# Content preview: .. _namespaces-guide:
#
# Using Namespaces
# ================
#
# A namespace is a logical grouping of jobs ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/getting-started.rst
# Content preview: .. _observability-getting-started:
#
# Ray Dashboard
# =============
#
# Ray provides a web-based dashboard ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-dag.rst
# Content preview: .. _ray-dag-guide:
#
# Lazy Computation Graphs with the Ray DAG API
# ===================================...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors.rst
# Content preview: .. _ray-remote-classes:
# .. _actor-guide:
#
# Actors
# ======
#
# Actors extend the Ray API from functions (t...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/architecture.md
# Content preview: (serve-architecture)=
#
# # Architecture
#
# In this section, we explore Serve's key architectural concept...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/key-concepts.rst
# Content preview: .. _observability-key-concepts:
#
# Key Concepts
# ============
#
# This section covers key concepts for mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-overview/getting-started.md
# Content preview: (gentle-intro)=
#
# # Getting Started
# Use Ray to scale applications on your laptop or the cloud. Choose...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/configure-logging.md
# Content preview: (configure-logging)=
#
# # Configuring Logging
#
# This guide helps you understand and modify the configur...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/examples/monte_carlo_pi.rst
# Content preview: .. _monte-carlo-pi:
#
# Monte Carlo Estimation of π
# ===========================
#
# This tutorial shows yo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/profiling.md
# Content preview: (profiling)=
# # Profiling
# Profiling is one of the most important debugging tools to diagnose performa...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/placement-group.rst
# Content preview: Placement Groups
# ================
#
# .. _ray-placement-group-doc-ref:
#
# Placement groups allow users to...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/async_api.rst
# Content preview: AsyncIO / Concurrency for Actors
# ================================
#
# Within a single actor process, it...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/configure-serve-deployment.md
# Content preview: (serve-configure-deployment)=
#
# # Configure Ray Serve deployments
#
# Ray Serve default values for deplo...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/miscellaneous.rst
# Content preview: Miscellaneous Topics
# ====================
#
# This page will cover some miscellaneous topics in Ray.
#
# ....
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/ray-generator.rst
# Content preview: .. _generators:
#
# Ray Generators
# ==============
#
# `Python generators <https://docs.python.org/3/howto...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/actors/actor-utils.rst
# Content preview: Utility Classes
# ===============
#
# Actor Pool
# ~~~~~~~~~~
#
# .. tab-set::
#
#     .. tab-item:: Python
#
#     ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-references/glossary.rst
# Content preview: .. _ray_glossary:
#
# Ray Glossary
# ============
#
# On this page you find a list of important terminology ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/objects.rst
# Content preview: .. _objects-in-ray:
#
# Objects
# =======
#
# In Ray, tasks and actors create and compute on objects. We ref...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/handling-dependencies.rst
# Content preview: .. _handling_dependencies:
#
# Environment Dependencies
# ========================
#
# Your Ray application ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-observability/user-guides/cli-sdk.rst
# Content preview: .. _observability-programmatic:
#
# Monitoring with the CLI or SDK
# ===============================
#
# Mon...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/fault_tolerance/actors.rst
# Content preview: .. _fault-tolerance-actors:
# .. _actor-fault-tolerance:
#
# Actor Fault Tolerance
# =====================
# ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/cluster/kubernetes/user-guides/kuberay-gcs-ft.md
# Content preview: (kuberay-gcs-ft)=
# # GCS fault tolerance in KubeRay
#
# Global Control Service (GCS) manages cluster-lev...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/key-concepts.rst
# Content preview: .. _core-key-concepts:
#
# Key Concepts
# ============
#
# This section overviews Ray's key concepts. These ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/memory-management.rst
# Content preview: .. _memory:
#
# Memory Management
# =================
#
# This page describes how memory management works in...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/scheduling/resources.rst
# Content preview: .. _core-resources:
#
# Resources
# =========
#
# Ray allows you to seamlessly scale your applications from ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-more-libs/modin/index.rst
# Content preview: .. _modin-on-ray:
#
# Using Pandas on Ray (Modin)
# ===========================
#
# Modin_, previously Panda...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/ray-core/cross-language.rst
# Content preview: .. _cross_language:
#
# Cross-Language Programming
# ==========================
#
# This page will show you ...
#
# Found in: ##File: /Users/allwefantasy/projects/ray/doc/source/serve/production-guide/fault-tolerance.md
# Content preview: (serve-e2e-ft)=
# # Add End-to-End Fault Tolerance
#
# This section helps you:
#
# * Provide additional faul...

# %% [markdown]
# ## 说明
#
# 1. ByzerStorageCache 会自动将文档分块并存储在 Byzer Storage 中
# 2. 支持向量搜索和全文检索
# 3. 文档会被自动向量化以支持语义搜索
# 4. 缓存会在第一次访问时自动构建
