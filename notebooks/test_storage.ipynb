# %%
import byzerllm

byzerllm.connect_cluster(address="auto",code_search_path=["/Users/allwefantasy/.auto-coder/storage/libs/byzer-retrieval-lib-0.1.11"])

retriever = byzerllm.ByzerRetrieval()
retriever.launch_gateway()

print(retriever.gateway())

retriever.cluster("byzerai_store")
# Out:
# 2024-06-07 10:27:59.763 | INFO     | byzerllm.utils.connect_ray:connect_cluster:37 - JDK 21 will be used (/Users/allwefantasy/.auto-coder/jdk-21.0.2.jdk/Contents/Home)...
# 2024-06-07 10:27:59,900	INFO worker.py:1564 -- Connecting to existing Ray cluster at address: 127.0.0.1:6379...
# 2024-06-07 10:27:59,902	INFO worker.py:1582 -- Calling ray.init() again after it has already been called.
# 21
# Actor(tech.mlsql.retrieval.RetrievalGateway, 8275f829aa1c778757d937700e000000)
# Actor(tech.mlsql.retrieval.RetrievalMaster, 981b8790483cc455c0b85cd70e000000)

# %%
import byzerllm

byzerllm.connect_cluster(address="ray://192.168.3.84:10001")

retriever = byzerllm.ByzerRetrieval()
retriever.launch_gateway()

print(retriever.gateway())

retriever.cluster("byzerai_store")
# Out:
# 2024-06-07 10:28:37.290 | INFO     | byzerllm.utils.connect_ray:connect_cluster:37 - JDK 21 will be used (/Users/allwefantasy/.auto-coder/jdk-21.0.2.jdk/Contents/Home)...
# 2024-06-07 10:28:37,293	INFO client_builder.py:244 -- Passing the following kwargs to ray.init() on the server: ignore_reinit_error
# ClientActorHandle(191fce012e919dce504c5b0607000000)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 10
#       6 retriever.launch_gateway()
#       8 print(retriever.gateway())
# ---> 10 retriever.cluster("byzerai_store")
#
# File /opt/miniconda3/envs/byzerllm/lib/python3.10/site-packages/byzerllm/utils/retrieval/__init__.py:177, in ByzerRetrieval.cluster(self, name)
#     174 if name in self.clusters:
#     175     return self.clusters[name]
# --> 177 cluster_ref = self.retrieval_gateway.getCluster.remote(name)
#     178 # master_ref.buildFromRayObjectStore.remote("db1","table1",data_refs)
#     179 cluster = ray.get(cluster_ref)
#
# File /opt/miniconda3/envs/byzerllm/lib/python3.10/site-packages/ray/util/client/common.py:494, in ClientActorHandle.__getattr__(self, key)
#     492     self._init_class_info()
#     493 if key not in self._method_signatures:
# --> 494     raise AttributeError(f"ClientActorRef has no attribute '{key}'")
#     495 return ClientRemoteMethod(
#     496     self,
#     497     key,
#     498     self._method_num_returns.get(key),
#     499     self._method_signatures.get(key),
#     500 )
#
# AttributeError: ClientActorRef has no attribute 'getCluster'
